# %%
 # Import necessary libraries
import os
import csv
import json
from googleapiclient.discovery import build

# Set your YouTube API key
api_key = ''

# %%
# Define a function to check if a comment is spam
def is_spam(comment):
    # Define a list of keywords commonly associated with spam
    spam_keywords = ['click', 'free', 'earn money', 'limited time offer', 'guaranteed', 'winner', 'dating', 'send', '100%', 'crypto']

    # Check if any spam keyword is present in the comment
    return any(keyword in comment.lower() for keyword in spam_keywords)

# %%
def get_like_count(comment_id):
    try:
        youtube = build('youtube', 'v3', developerKey=api_key)
        comment_response = youtube.commentThreads().list(
            part='snippet',
            id=comment_id
        ).execute()

        if 'items' in comment_response and comment_response['items']:
            like_count = comment_response['items'][0]['snippet']['topLevelComment']['snippet']['likeCount']
            return like_count
    except Exception as e:
        print(f"Error fetching like count for Comment ID: {comment_id}, Error: {str(e)}")
    return None

# %%
def fetch_like_counts(input_csv, output_csv):
    with open(input_csv, mode='r', encoding='utf-8') as input_file, \
            open(output_csv, mode='w', newline='', encoding='utf-8') as output_file:
        reader = csv.DictReader(input_file)
        fieldnames = ['COMMENT_ID', 'AUTHOR', 'DATE', 'CONTENT', 'SUMMARY', 'LIKE_COUNT', 'CLASS']
        writer = csv.DictWriter(output_file, fieldnames=fieldnames)
        writer.writeheader()

        for row in reader:
            comment_id = row['COMMENT_ID']
            author = row['AUTHOR']
            date = row['DATE']
            content = row['CONTENT']
            summary = row['SUMMARY']
            class_label = row['CLASS']

            like_count = get_like_count(comment_id)
            writer.writerow({
                'COMMENT_ID': comment_id,
                'AUTHOR': author,
                'DATE': date,
                'CONTENT': content,
                'SUMMARY': summary,
                'LIKE_COUNT': like_count,
                'CLASS': class_label
            })
            if like_count is not None:
                print(f"Comment ID: {comment_id}, Like Count: {like_count}")
            else:
                print(f"Comment ID: {comment_id}, Like Count: Not Available")

# %%
def video_comments(video_id):
    youtube = build('youtube', 'v3', developerKey=api_key)
    video_response = youtube.commentThreads().list(
        part='snippet',
        videoId=video_id
    ).execute()

    with open('all_comments.csv', mode='w', newline='', encoding='utf-8') as all_comments_file, \
         open('spam_comments.csv', mode='w', newline='', encoding='utf-8') as spam_comments_file:

        all_comments_fieldnames = ['COMMENT_ID', 'AUTHOR', 'DATE', 'CONTENT', 'LIKE_COUNT', 'CLASS']
        spam_comments_fieldnames = ['COMMENT_ID', 'AUTHOR', 'DATE', 'CONTENT', 'LIKE_COUNT',  'CLASS']

        all_comments_writer = csv.DictWriter(all_comments_file, fieldnames=all_comments_fieldnames)
        all_comments_writer.writeheader()

        spam_comments_writer = csv.DictWriter(spam_comments_file, fieldnames=spam_comments_fieldnames)
        spam_comments_writer.writeheader()

        while video_response:
            for item in video_response['items']:
                comment_id = item['snippet']['topLevelComment']['id']
                author = item['snippet']['topLevelComment']['snippet']['authorDisplayName']
                date = item['snippet']['topLevelComment']['snippet']['publishedAt']
                content = item['snippet']['topLevelComment']['snippet']['textDisplay']
                like_count = item['snippet']['topLevelComment']['snippet']['likeCount']
                is_spam_comment = is_spam(content)

                all_comments_writer.writerow({
                    'COMMENT_ID': comment_id,
                    'AUTHOR': author,
                    'DATE': date,
                    'CONTENT': content,
                    'LIKE_COUNT' : like_count,
                    'CLASS': '1' if is_spam_comment else '0'
                })

                if is_spam_comment:
                    spam_comments_writer.writerow({
                        'COMMENT_ID': comment_id,
                        'AUTHOR': author,
                        'DATE': date,
                        'LIKE_COUNT' :like_count,
                        'CONTENT': content
                    })
                    print(f"Spam Comment ID: {comment_id}")
                    print(f"Author: {author}")
                    print(f"Date: {date}")
                    print(f"Content: {content}")
                    print(f"Like Count: ", {like_count})

            if 'nextPageToken' in video_response:
                video_response = youtube.commentThreads().list(
                    part='snippet',
                    videoId=video_id,
                    pageToken=video_response['nextPageToken']
                ).execute()
            else:
                break

# %%
input_csv = 'Youtube05-Combined.csv'

# Specify the output CSV file for like counts
output_csv = 'comment_like_counts.csv'

# Call the function to fetch and save like counts based on comment IDs
fetch_like_counts(input_csv, output_csv)
# Out:
# Comment ID: LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU, Like Count: Not Available
# Comment ID: LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A, Like Count: Not Available
# Comment ID: LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8, Like Count: Not Available
# Error fetching like count for Comment ID: z13jhp0bxqncu512g22wvzkasxmvvzjaz04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13jhp0bxqncu512g22wvzkasxmvvzjaz04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13jhp0bxqncu512g22wvzkasxmvvzjaz04, Like Count: Not Available
# Error fetching like count for Comment ID: z13fwbwp1oujthgqj04chlngpvzmtt3r3dw, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13fwbwp1oujthgqj04chlngpvzmtt3r3dw&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13fwbwp1oujthgqj04chlngpvzmtt3r3dw, Like Count: Not Available
# Comment ID: LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc, Like Count: Not Available
# Error fetching like count for Comment ID: z13lfzdo5vmdi1cm123te5uz2mqig1brz04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13lfzdo5vmdi1cm123te5uz2mqig1brz04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13lfzdo5vmdi1cm123te5uz2mqig1brz04, Like Count: Not Available
# Error fetching like count for Comment ID: z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k, Like Count: Not Available
# Error fetching like count for Comment ID: z13ttt1jcraqexk2o234ghbgzxymz1zzi04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13ttt1jcraqexk2o234ghbgzxymz1zzi04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13ttt1jcraqexk2o234ghbgzxymz1zzi04, Like Count: Not Available
# Error fetching like count for Comment ID: z12avveb4xqiirsix04chxviiljryduwxg0, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12avveb4xqiirsix04chxviiljryduwxg0&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12avveb4xqiirsix04chxviiljryduwxg0, Like Count: Not Available
# Error fetching like count for Comment ID: z13auhww3oufjn1qo04ci3grqqjmfjexxuo0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13auhww3oufjn1qo04ci3grqqjmfjexxuo0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13auhww3oufjn1qo04ci3grqqjmfjexxuo0k, Like Count: Not Available
# Error fetching like count for Comment ID: z13xit5agm2zyh4f523rst2gowmbx5bml, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13xit5agm2zyh4f523rst2gowmbx5bml&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13xit5agm2zyh4f523rst2gowmbx5bml, Like Count: Not Available
# Error fetching like count for Comment ID: z13pejoiuozwxtdu323dspopnri4xts0f, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13pejoiuozwxtdu323dspopnri4xts0f&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13pejoiuozwxtdu323dspopnri4xts0f, Like Count: Not Available
# Error fetching like count for Comment ID: z121zxaxsq25z5k5o04ch1o5jqqfij3gtm40k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z121zxaxsq25z5k5o04ch1o5jqqfij3gtm40k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z121zxaxsq25z5k5o04ch1o5jqqfij3gtm40k, Like Count: Not Available
# Error fetching like count for Comment ID: z12oglnpoq3gjh4om04cfdlbgp2uepyytpw0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12oglnpoq3gjh4om04cfdlbgp2uepyytpw0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12oglnpoq3gjh4om04cfdlbgp2uepyytpw0k, Like Count: Not Available
# Error fetching like count for Comment ID: z13phrmwrkfisn5er22eyrbpbvaiwfvwf04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13phrmwrkfisn5er22eyrbpbvaiwfvwf04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13phrmwrkfisn5er22eyrbpbvaiwfvwf04, Like Count: Not Available
# Error fetching like count for Comment ID: z13bgdvyluihfv11i22rgxwhuvabzz1os04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13bgdvyluihfv11i22rgxwhuvabzz1os04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13bgdvyluihfv11i22rgxwhuvabzz1os04, Like Count: Not Available
# Error fetching like count for Comment ID: z13vxpnoxsyeuv2jr04cctprprb1slnxdf4, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13vxpnoxsyeuv2jr04cctprprb1slnxdf4&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13vxpnoxsyeuv2jr04cctprprb1slnxdf4, Like Count: Not Available
# Error fetching like count for Comment ID: z12qth5j0ob1fx3q404chvy4fz32tbkpllk0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12qth5j0ob1fx3q404chvy4fz32tbkpllk0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12qth5j0ob1fx3q404chvy4fz32tbkpllk0k, Like Count: Not Available
# Error fetching like count for Comment ID: z13etj0bclzfztuwc04cgfvrgmf3fvjor1g, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13etj0bclzfztuwc04cgfvrgmf3fvjor1g&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13etj0bclzfztuwc04cgfvrgmf3fvjor1g, Like Count: Not Available
# Error fetching like count for Comment ID: z12axnji5w2axxht522thb3bktvqjdlbp04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12axnji5w2axxht522thb3bktvqjdlbp04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12axnji5w2axxht522thb3bktvqjdlbp04, Like Count: Not Available
# Error fetching like count for Comment ID: z13ozdmr4lf3uzc5z04cix2zkyjzgvcyemw0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13ozdmr4lf3uzc5z04cix2zkyjzgvcyemw0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13ozdmr4lf3uzc5z04cix2zkyjzgvcyemw0k, Like Count: Not Available
# Error fetching like count for Comment ID: z12ohdxjtsatvppjb04cctprprb1slnxdf4, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12ohdxjtsatvppjb04cctprprb1slnxdf4&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12ohdxjtsatvppjb04cctprprb1slnxdf4, Like Count: Not Available
# Error fetching like count for Comment ID: z12ntlcqht2bvjewi04cf1up0xjvs5lq3mc0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12ntlcqht2bvjewi04cf1up0xjvs5lq3mc0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12ntlcqht2bvjewi04cf1up0xjvs5lq3mc0k, Like Count: Not Available
# Comment ID: LZQPQhLyRh9EXArr4ZnVcDonSbvSMHKYOT24e_qR6fE, Like Count: Not Available
# Comment ID: LZQPQhLyRh9y57URF7qpZRk3MVAJNLNhhZga_5YWBU8, Like Count: Not Available
# Comment ID: LZQPQhLyRh9vw01Xvvw5yWzZEUOPG1hSgRMHep55-Yw, Like Count: Not Available
# Error fetching like count for Comment ID: z13kszcinpnvc34v2234fnpxkpmlw3nhc04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13kszcinpnvc34v2234fnpxkpmlw3nhc04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13kszcinpnvc34v2234fnpxkpmlw3nhc04, Like Count: Not Available
# Error fetching like count for Comment ID: z13tj514otzlurfbc04ccjwhrnmej1iihqw0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13tj514otzlurfbc04ccjwhrnmej1iihqw0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13tj514otzlurfbc04ccjwhrnmej1iihqw0k, Like Count: Not Available
# Error fetching like count for Comment ID: z13zvh1rmk3cf3mby04civbq5mjtddmbysk0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13zvh1rmk3cf3mby04civbq5mjtddmbysk0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13zvh1rmk3cf3mby04civbq5mjtddmbysk0k, Like Count: Not Available
# Error fetching like count for Comment ID: z120y3ribybzdf3fj23sf1rpgq3cex0sh, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z120y3ribybzdf3fj23sf1rpgq3cex0sh&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z120y3ribybzdf3fj23sf1rpgq3cex0sh, Like Count: Not Available
# Error fetching like count for Comment ID: z13autsqgzblcx3w104chr4r2kexd10rxc0, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13autsqgzblcx3w104chr4r2kexd10rxc0&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13autsqgzblcx3w104chr4r2kexd10rxc0, Like Count: Not Available
# Error fetching like count for Comment ID: z12wvpxppxz3ifk3j224cbsgqraherzrg04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12wvpxppxz3ifk3j224cbsgqraherzrg04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12wvpxppxz3ifk3j224cbsgqraherzrg04, Like Count: Not Available
# Error fetching like count for Comment ID: z121e3zq5kj3ip2ch22ks3vwekuaibrgc04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z121e3zq5kj3ip2ch22ks3vwekuaibrgc04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z121e3zq5kj3ip2ch22ks3vwekuaibrgc04, Like Count: Not Available
# Error fetching like count for Comment ID: z13kxpqqssa0hlryd04cc1dxeyyngljjngk, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13kxpqqssa0hlryd04cc1dxeyyngljjngk&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13kxpqqssa0hlryd04cc1dxeyyngljjngk, Like Count: Not Available
# Error fetching like count for Comment ID: z13iuzxwamqhzppyp04cdz1amyzpfdnpdns0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13iuzxwamqhzppyp04cdz1amyzpfdnpdns0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13iuzxwamqhzppyp04cdz1amyzpfdnpdns0k, Like Count: Not Available
# Error fetching like count for Comment ID: z12txle43yfhvt0f323eghbxivmuytieq, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12txle43yfhvt0f323eghbxivmuytieq&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12txle43yfhvt0f323eghbxivmuytieq, Like Count: Not Available
# Error fetching like count for Comment ID: z13zj1grjzqhhxzlj23gdpzaovunwnn0f, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13zj1grjzqhhxzlj23gdpzaovunwnn0f&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13zj1grjzqhhxzlj23gdpzaovunwnn0f, Like Count: Not Available
# Error fetching like count for Comment ID: z13csdop4venytrru04cf11q1wmbdvkrfpo0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13csdop4venytrru04cf11q1wmbdvkrfpo0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13csdop4venytrru04cf11q1wmbdvkrfpo0k, Like Count: Not Available
# Error fetching like count for Comment ID: z13ce52jzwfitrkup23din4ojputijen3, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13ce52jzwfitrkup23din4ojputijen3&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13ce52jzwfitrkup23din4ojputijen3, Like Count: Not Available
# Error fetching like count for Comment ID: z13phfyxhovav1hl122bf5iidumufzbel, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13phfyxhovav1hl122bf5iidumufzbel&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13phfyxhovav1hl122bf5iidumufzbel, Like Count: Not Available
# Error fetching like count for Comment ID: z13xytyybsypw34yv04cc33xkke1grugh2w, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13xytyybsypw34yv04cc33xkke1grugh2w&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13xytyybsypw34yv04cc33xkke1grugh2w, Like Count: Not Available
# Error fetching like count for Comment ID: z13vsbcjwrybe3hsf23sgvnxfr3zxnion04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13vsbcjwrybe3hsf23sgvnxfr3zxnion04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13vsbcjwrybe3hsf23sgvnxfr3zxnion04, Like Count: Not Available
# Error fetching like count for Comment ID: z12jvnua2tifirkvk23cfjtpxwmgxfch004, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12jvnua2tifirkvk23cfjtpxwmgxfch004&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12jvnua2tifirkvk23cfjtpxwmgxfch004, Like Count: Not Available
# Error fetching like count for Comment ID: z13stv3brxe1snv2i225fnvganneudej004, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13stv3brxe1snv2i225fnvganneudej004&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13stv3brxe1snv2i225fnvganneudej004, Like Count: Not Available
# Error fetching like count for Comment ID: z12ktfsarrv0wdj3p22ifbxz3zn2fthhw04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12ktfsarrv0wdj3p22ifbxz3zn2fthhw04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12ktfsarrv0wdj3p22ifbxz3zn2fthhw04, Like Count: Not Available
# Error fetching like count for Comment ID: z121znjjloycwtjf2233dfo5esfggn3lj, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z121znjjloycwtjf2233dfo5esfggn3lj&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z121znjjloycwtjf2233dfo5esfggn3lj, Like Count: Not Available
# Error fetching like count for Comment ID: z125zbmwryjwxzx4504cfjzwbtztuvkif3c, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z125zbmwryjwxzx4504cfjzwbtztuvkif3c&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z125zbmwryjwxzx4504cfjzwbtztuvkif3c, Like Count: Not Available
# Error fetching like count for Comment ID: z12stpyqaonsercxw04cjbr4dlnrxd34soo0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12stpyqaonsercxw04cjbr4dlnrxd34soo0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12stpyqaonsercxw04cjbr4dlnrxd34soo0k, Like Count: Not Available
# Error fetching like count for Comment ID: z13nvr2xayrwffsio04cj3zwyuf3vb1imdg, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13nvr2xayrwffsio04cj3zwyuf3vb1imdg&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13nvr2xayrwffsio04cj3zwyuf3vb1imdg, Like Count: Not Available
# Error fetching like count for Comment ID: z13uzhdomzvbffvwa04cgplq2zewfz2hm2k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13uzhdomzvbffvwa04cgplq2zewfz2hm2k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13uzhdomzvbffvwa04cgplq2zewfz2hm2k, Like Count: Not Available
# Error fetching like count for Comment ID: z13ucxa51rnftvu2j22if5oihq2qipjlp, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13ucxa51rnftvu2j22if5oihq2qipjlp&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13ucxa51rnftvu2j22if5oihq2qipjlp, Like Count: Not Available
# Error fetching like count for Comment ID: z120grixiomvyvbga04cfl24csz5jf4zzuc0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z120grixiomvyvbga04cfl24csz5jf4zzuc0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z120grixiomvyvbga04cfl24csz5jf4zzuc0k, Like Count: Not Available
# Error fetching like count for Comment ID: z13gevgohyzktbztz22mcrcpntfxvpvan04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13gevgohyzktbztz22mcrcpntfxvpvan04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13gevgohyzktbztz22mcrcpntfxvpvan04, Like Count: Not Available
# Error fetching like count for Comment ID: z12gy5tb2kase1nix04cipry3mf1wh5grko0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12gy5tb2kase1nix04cipry3mf1wh5grko0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12gy5tb2kase1nix04cipry3mf1wh5grko0k, Like Count: Not Available
# Error fetching like count for Comment ID: z13hxl3yoqmlvdlnu23atlqgsoyevlsse, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13hxl3yoqmlvdlnu23atlqgsoyevlsse&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13hxl3yoqmlvdlnu23atlqgsoyevlsse, Like Count: Not Available
# Error fetching like count for Comment ID: z12gv5qoconqsbe0h221wljgmwe4v1nmu, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12gv5qoconqsbe0h221wljgmwe4v1nmu&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12gv5qoconqsbe0h221wljgmwe4v1nmu, Like Count: Not Available
# Error fetching like count for Comment ID: z13eepr4dyjet34pt04cgr1rctvwsvqwqso0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13eepr4dyjet34pt04cgr1rctvwsvqwqso0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13eepr4dyjet34pt04cgr1rctvwsvqwqso0k, Like Count: Not Available
# Error fetching like count for Comment ID: z121st5w5k3ui1veg22zirn4gkr5tby2v, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z121st5w5k3ui1veg22zirn4gkr5tby2v&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z121st5w5k3ui1veg22zirn4gkr5tby2v, Like Count: Not Available
# Error fetching like count for Comment ID: z13osnp4hnzry1o15224yfzbotr0epxqk04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13osnp4hnzry1o15224yfzbotr0epxqk04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13osnp4hnzry1o15224yfzbotr0epxqk04, Like Count: Not Available
# Error fetching like count for Comment ID: z12rgllzmwnfuba4h04ch3njgy2fg3ryerg0k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12rgllzmwnfuba4h04ch3njgy2fg3ryerg0k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12rgllzmwnfuba4h04ch3njgy2fg3ryerg0k, Like Count: Not Available
# Error fetching like count for Comment ID: z12rc1ebfvrmufz5w04ccl2pmt3ih5dymq40k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12rc1ebfvrmufz5w04ccl2pmt3ih5dymq40k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12rc1ebfvrmufz5w04ccl2pmt3ih5dymq40k, Like Count: Not Available
# Error fetching like count for Comment ID: z13mcpkzpoz1hj3o304cfd3oouf2tj1rnk40k, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z13mcpkzpoz1hj3o304cfd3oouf2tj1rnk40k&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z13mcpkzpoz1hj3o304cfd3oouf2tj1rnk40k, Like Count: Not Available
# Error fetching like count for Comment ID: z121cnnzhsybzjkt122nsviacsekvvt1r, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z121cnnzhsybzjkt122nsviacsekvvt1r&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z121cnnzhsybzjkt122nsviacsekvvt1r, Like Count: Not Available
# Error fetching like count for Comment ID: z125gx4g5wemgtyvr23ryvlrbxjvwl2mi, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z125gx4g5wemgtyvr23ryvlrbxjvwl2mi&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z125gx4g5wemgtyvr23ryvlrbxjvwl2mi, Like Count: Not Available
# ...
# Comment ID: _2viQ_Qnc69ShtSmsaBOGFHrTAVCkLAtpOr40oiL5Yg, Like Count: Not Available
# Comment ID: _2viQ_Qnc69fyi7qH4TDPB7CSJnioSrJi3CoQXBbjCo, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_kxEjV8Ut57SeEGdqSKmC8VGP1K38Q2qY, Like Count: Not Available
# Comment ID: _2viQ_Qnc69wKf5GrJmQ5IZqKaEKr-rIjB5OqBC1Y_M, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-I58GFzl5H7twI_SISp0gQ8DndetxF2i0, Like Count: Not Available
# Comment ID: _2viQ_Qnc69N53yIJS3ZrRHmdbS1qZLnkXgodzIegJM, Like Count: Not Available
# Comment ID: _2viQ_Qnc68eqIzELH00rh9umGlUKSRuQvWZAXhr_qM, Like Count: Not Available
# Comment ID: _2viQ_Qnc69h-dBshypMERLv5by8Rf7I8TSLnP1Lnoo, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-grcnVFTtwnhvC9tpgVG33p5a0AZHKlLI, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-q29okw74KTmVXCvhacMZ5NjAiYdAwHww, Like Count: Not Available
# Comment ID: _2viQ_Qnc69vgWhC2acrKSH-tvjKq1KuKBca1UtB8wk, Like Count: Not Available
# Comment ID: _2viQ_Qnc69mufWqn8FcFN6u6tahNMkNWgB4-jKb2hs, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_QZJzAERyAVzhcr3jy2ctVM4zQMfesQWQ, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_qs30Ph_whafzKoWVyh_xIYpN3-7U_VmA, Like Count: Not Available
# Comment ID: _2viQ_Qnc69BVRuBYCJ6ik7gdMwTiBRS9DDnTjNs-Gg, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-nD73Whq8IPs5SpJ3v8OO6PlgvyoopAqQ, Like Count: Not Available
# Comment ID: _2viQ_Qnc68tZfiBq8O7pExj1MmWcnorsu-kyc0Jz8Q, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-k1VSPmCd2mrSAAQXChBMxF7oeJGCepUU, Like Count: Not Available
# Comment ID: _2viQ_Qnc68jroUSzJhg6jrxFj86oxZrAtGB_PWbOm4, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-dfXGv_qVn1mdoRB9dAfp4ppjUsNu-GDU, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_eMN0NwT5paySjJPFbN5xI9W8C1Bwoq1U, Like Count: Not Available
# Comment ID: _2viQ_Qnc68DyUSaxqDmv-6yHPVUpKeYAZhrh2PUMZg, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-TLlBlT0itl1DbMJQGBx_6ZbscBXA3Nww, Like Count: Not Available
# Comment ID: _2viQ_Qnc69wrsSgR2azuokmk5-WDQVVI2lCV-WqJGA, Like Count: Not Available
# Comment ID: _2viQ_Qnc69JZ1f3TJQWKMLhmdP0inDDPwOvzMQiFjE, Like Count: Not Available
# Comment ID: _2viQ_Qnc68fX3dYsfYuM-m4ELMJvxOQBmBOFHqGOk0, Like Count: Not Available
# Comment ID: _2viQ_Qnc68fX3dYsfYuM-m4ELMJvxOQBmBOFHqGOk0, Like Count: Not Available
# Comment ID: _2viQ_Qnc69d37KEGZqBfleT0syzA1usOUM89zKNBGs, Like Count: Not Available
# Comment ID: _2viQ_Qnc68DYuhKc_RZjva7trZ1b4AU28tnu1S8KAc, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-adLPqdl8Te15fgwPQaG8KLlyJGrtxbic, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-1fj_YPI5S4X9e9VnvAzoykRbwZGAlYgo, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-pstqJtz-1zkROrvYIsPoBlOCr8i_tLIM, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_-kHjHykSk9uu3A0NCryrDEa3pLXbX_C8, Like Count: Not Available
# Comment ID: _2viQ_Qnc68357a4KUMONoAtNJ71qlc4cCzOC5Q5U3E, Like Count: Not Available
# Comment ID: _2viQ_Qnc684Wob4j6dbLPeYzFG8ZB3h1sgfYm4SDsI, Like Count: Not Available
# Comment ID: _2viQ_Qnc694tFwvOhmFcrz4GGaxVyxStdYmFH-nR68, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_lxLB2IBIspObma9o3R5-8SwQnc8zq9Sk, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_JXmouLzw0-ItjbZCiPZjIwo__lIyDsj8, Like Count: Not Available
# Comment ID: _2viQ_Qnc69xHT0POK7QFVihno_v_II_pWLoDMoFPXo, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-DELwfmf160qnTke41ME1MAOWHfxdLYyU, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_ahzf6NP9Anh6ef2byWNEcrFHd9swO25s, Like Count: Not Available
# Comment ID: _2viQ_Qnc68hNPCfXGAxIxW9V7wcDDxSdp-gyHTkgho, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-9_PSkIwb3ThN5ebV8wCU8DxCWTgTSOkc, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_rAWi6BK2OqTQ_Ob0X8DkXenO0qL0qWm0, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-kUg8jc2n9-Cudm5lEsM-cSzIjF182TJo, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_xOpLcxFFeUEgEYvQjttGcFYeMZ2lK4yY, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_7GI-VeVlj8gEzvkgATIX3jK-7J1kwWEY, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_IouTIqS8ontdQofcZwF4O6cG0-rFPXvo, Like Count: Not Available
# Comment ID: _2viQ_Qnc68MKhLnK71z12gu878i_A0sdfmpA0RvgOE, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-M2Gjq_TCThUeRGBbSNsclbeFll-ETDD8, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_N2zOGpILFMw84xtq3hW1Evqp4K2VjCiM, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-M29TD0eSrvhfMU9n1v7kunCbSMqnODXg, Like Count: Not Available
# Comment ID: _2viQ_Qnc680Rh_y5Dlwtkr_llWVOG7ZQdmNVip_dno, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_bcubCrs8YncM7B9016OeduR9RR-cKRb4, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-pgdb3FeyKxBCq6-zYy7OAn_tWkX5Xgz4, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_f7lY0xamQZtpqGkzqcC4U25KdJTNXqfo, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_umVgV0fI-CSScDHuFxNHIVvezCGhajW8, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_eGfHB415UkNWBszO-GzLm9_Q0_qWsNLI, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-uO31Z6WO5RUUpcrJ43ISst2uruk4y6TI, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_XQHOjsmnALH1Quwy3tmW6KKW67LkNGoQ, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-LmEEd3Pfnu9Sr-MT4sVCt84E5BYHGnM0, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-TMFClPlfFIBHdy_HbPbLyMhBsuEz5Lj8, Like Count: Not Available
# Comment ID: _2viQ_Qnc69D1Jxs1IlkkF0Xzce0uBoJN_OzDHnfmV0, Like Count: Not Available
# Comment ID: _2viQ_Qnc68Lfu14asBabOAcqL9B7Anp_6zX66rSWP0, Like Count: Not Available
# Comment ID: _2viQ_Qnc68dceJbTRNTP2sksMxa_lm35LaCu_jPluY, Like Count: Not Available
# Comment ID: _2viQ_Qnc69A12xULkAOn5BEAGFKxQTTP02SSbsMsmc, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-CRJO_6pvsByopsnD3qpCbK0IPhkvTuS8, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_onwOgxju-DV6WkqHZEOztCXD04EgEFBU, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_rdI1pDiJrFRv9uqSk3MizTk-rQeALntU, Like Count: Not Available
# Comment ID: _2viQ_Qnc69uhVbXr8SjkhLHu7T1HOxqrEF1f6h8vUA, Like Count: Not Available
# Comment ID: _2viQ_Qnc69ETVqiialEz0s1k4Xnlmwuu1m1Hr-YzRE, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_0DIjqw5n_WRhiiEtCGnZgvPPZJgZwPjU, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_B7ncS0M0zl0VC4SZ22T1ZO_GNhI1IWTM, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_NswChsPPlG9Uf0ofpNvP1p2xoIoIi558, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-adCzTDLAhqNVQ5hFYcjPyPI5m7pHY4BY, Like Count: Not Available
# Comment ID: _2viQ_Qnc68Q2-t0ozy5t7pGOgxPEnJYsDVa48udRIQ, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-jidHqOHj6hf4XnhflHNGicw4dL1vZRvQ, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_Z85BMDurr0H0sdfTiCwy1hAg5aytbkWg, Like Count: Not Available
# Comment ID: _2viQ_Qnc68mfmp-D4hvnrhJa3Z4I1G4FbP0hvk2rA4, Like Count: Not Available
# Comment ID: _2viQ_Qnc69hsj2kD8NcqZ3j5iFIB8o7VpIkf2JL1uU, Like Count: Not Available
# Comment ID: _2viQ_Qnc689wLmW6MeEZ9rga7i5ZYz1G3IZmSHeWEQ, Like Count: Not Available
# Comment ID: _2viQ_Qnc68GD5OuwI5hh_dOADJdyjRye8XvH_ucDSk, Like Count: Not Available
# Comment ID: _2viQ_Qnc69pXwaj0QM6Ewdhza8RXqWKlQcJUj8dPWg, Like Count: Not Available
# Comment ID: _2viQ_Qnc69vjtRxop92H6OWpxKYZu4Mokxff2OzDKE, Like Count: Not Available
# Comment ID: _2viQ_Qnc68o-ddWZf7571X8w1r4L1zFzYihOdQ0tAY, Like Count: Not Available
# Comment ID: _2viQ_Qnc69IkplAQG3gXtQ9y40h_rrQsgjJk3v_MOk, Like Count: Not Available
# Comment ID: _2viQ_Qnc68BaXGVkheyDuF79FU05zYyvT-Q5xFyHzM, Like Count: Not Available
# Comment ID: _2viQ_Qnc69FP_GeK2URWIx47LwY10_rRmCqfFk0_Uc, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-_SpDzX8DwHaw3bUkE-owmcb7eOEPPurs, Like Count: Not Available
# Comment ID: _2viQ_Qnc69hcZfDZYAej5tFyv6a7kX1xwJGCG1T3qY, Like Count: Not Available
# Comment ID: _2viQ_Qnc68RkAwC42s4YBDdCJYELSb6UiuZri58Kn0, Like Count: Not Available
# Comment ID: _2viQ_Qnc686iGqhAHKEeclAngy8MjvOxAo1hFpatHc, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_38op-kBrdA4xwd0KSYefHqdbeuljSgzM, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_FlLJN0izQaKVQNe6LGDmPZMmkVDjjymE, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_8ffRCQd5tgg-gWMV557Vkqa4Yz1P4m8s, Like Count: Not Available
# Comment ID: _2viQ_Qnc68WY7dYEqu0Gx6d1pRcC1S2JCkyKwPxBEE, Like Count: Not Available
# Comment ID: _2viQ_Qnc69saopRmKcZavlgi69aQhlFsDzUkMqZ1xQ, Like Count: Not Available
# Comment ID: _2viQ_Qnc68d0oIh4oQZVITOixgFDyWwZLzk0gK604I, Like Count: Not Available
# Comment ID: _2viQ_Qnc68eAk1RuUiWxIBm6SyxuC5iUi2qYbz8gmE, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_VU7QGeFKeturpUPwo-jDiYu85rbtMPS8, Like Count: Not Available
# Comment ID: _2viQ_Qnc69LTbY1BZ2vaOiGknD4szgHVHc6FI3mBAw, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_K0UFJiCGKpBw86dGcjZIV5Nt7ke46swQ, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-oktCjZuAEscq8DxT2RHFY1nfSS_hCWf0, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-8fXmwJsxpt64D862oCsb0cCfnoF_7Pwg, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-r7fiKCYAGotgCULCIx695QCHaAZDKHBM, Like Count: Not Available
# Comment ID: _2viQ_Qnc69wycunZGebHhH3CnhNYYLjUzHrnXdzkV8, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_JXdgRpQbBADKUYa1ESkXLxO1oW_ouaxU, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-76PJqtBpzwmOHbogHlzWG9RSSpe-Kr1s, Like Count: Not Available
# Comment ID: _2viQ_Qnc69AVbPU2gXuoLiAOr6muFqsr7sm17CjhX4, Like Count: Not Available
# Comment ID: _2viQ_Qnc69WextJrbKBgZtDWQiRWlkxS317fouQMYc, Like Count: Not Available
# Comment ID: _2viQ_Qnc69hCwlRZTPP7JejZgoroMu8egbziE1hSAc, Like Count: Not Available
# Comment ID: _2viQ_Qnc68cUterDmjc7m6MyHkz-ADLt28bgxo9TJE, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-jJD3XsdtbSW-9MCGB_Xp0nl2NhTBgdGo, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-k-Ldaj1pejT7IsYIELp1Npwz5tQAkuX0, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_m4670hGGDwGjYreYnRR8359YYmuS_lDA, Like Count: Not Available
# Comment ID: _2viQ_Qnc68kPR6lRkhBHXUX2dGt04-4RgzINpv8Yhk, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-NqqHR40AwZGnQV7in6y6YrSbMW9wRZXM, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-lW0XpQ5szMbbKcq0fuK2p4lDhPbQpGn0, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-m9RqGULP5B8P1SH2WqvKu3TnN7rBk2CI, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_hoPuz8gsl9ZFXFZGPESkLzYU9REwL880, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_yLBNpqStGB5UF3nD3razd5EYm60rdOKs, Like Count: Not Available
# Comment ID: _2viQ_Qnc68ohvE0UyLK_gdOAe__2iDVi8CqVB97qeA, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_nI97BKqkdeX9pbSkcDCWrg5cDb74C7kk, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_fFzltk8kvomVzwfkCdIZApG5fa2-gZRw, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_HD2WpfyqvoRqTXGoLMA_zfTPGbWKrYyw, Like Count: Not Available
# Comment ID: _2viQ_Qnc68ked0J7OAfephXPfR-pvW7HiuIC5ZRduI, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-hMCH52bsWm38Ur7cdAPSdC3SmpC0-9YM, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-MfwtDpLuGhWQ2o-4TN6bmxidyzSzQuc0, Like Count: Not Available
# Comment ID: _2viQ_Qnc69datZTHIa2E_Ejo2gIk6WmZJJUiCSMLTw, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_Zg0GECxJ4iGuOCFBrzjOBZguGqOhU5ms, Like Count: Not Available
# Comment ID: _2viQ_Qnc69swE48B0wgwJijgdZ2KbSVUK5TSpqoYDg, Like Count: Not Available
# Comment ID: _2viQ_Qnc69TuQDH0yVDsXPiyJCNNBrDiYhDY66Xu8g, Like Count: Not Available
# Comment ID: _2viQ_Qnc6870xv47G-__kc0IimrvnGFcLXaLnJsiFE, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-qc6sKOH4U0o8eIL4tVjojc-DyDYkkvWk, Like Count: Not Available
# Comment ID: _2viQ_Qnc6978LweIjWZsjP3qK1bgFSYyumKWxPsq_I, Like Count: Not Available
# Comment ID: _2viQ_Qnc6812QtCcbHa3ZgmjznXhr0Ar324LJpkSHE, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_QPhRwA4ZFbviXqXHvKyKJb7UivUZFUH0, Like Count: Not Available
# Comment ID: _2viQ_Qnc69bp77hGJ6em0Gm1Fg_TLmNoUuS_ydlofg, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_Hcona9vbTbZqnb5SyyHKi7PxVC-KkfTY, Like Count: Not Available
# Comment ID: _2viQ_Qnc69r15LuL8TDbisnTJ_hf5RfcyJAyoMC5eo, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-h3o48aXYmI_xInBcH9saCmEK627IQm68, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-LyNEXRld9VERRpRICrMPNxpnGjL8ZsF4, Like Count: Not Available
# Comment ID: _2viQ_Qnc69zyetF6GsHRzYGyXl4u5kg0Sm-nP-pupI, Like Count: Not Available
# Comment ID: _2viQ_Qnc699u36gNm3NRoq1quIaJWRNrftGEEZM3J4, Like Count: Not Available
# Comment ID: _2viQ_Qnc68LqKGb40V2ImKQYcp1ZqpHrCCMFqMCcA4, Like Count: Not Available
# Comment ID: _2viQ_Qnc68Qq98m0mmx4rlprYiD6aYgMb2x3bdupEM, Like Count: Not Available
# Comment ID: _2viQ_Qnc698fLCQzZmRt1CqPhf0L6mchwWG5gsUlzk, Like Count: Not Available
# Comment ID: _2viQ_Qnc68sxLpsBQ1cPk_LLH91SMsRav51KmhIoQw, Like Count: Not Available
# Comment ID: _2viQ_Qnc69Nq0Ytk1jCpzWPCrpGEk6T7cdVAxfSlAk, Like Count: Not Available
# Comment ID: _2viQ_Qnc68wE6_oU558uTupID2DHHu6smRW0Yr5mVs, Like Count: Not Available
# Comment ID: _2viQ_Qnc685qxAXpoMI-8aTnd7plcAbmTrvD_G2Czw, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-F0FnQlt7edQt9rRqV7Clx74E8hyKAVt0, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-Lev7nxVg9RnkxHYNAykFf9lV9qiEIFJY, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_sGHV0-pAXNa1RF9Xja5vmr53ULlzlG3g, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-1oZCLsUWjl3-g4QrWxMQXsSTs2Hy4MGI, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_YN7xFNAg14zX99Y614Salf57yOcrBRSw, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_fyjM2m-ismUToowpNFauwtldKlfjbtIk, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_AXZ4E5CeA3LHE36RAijd3QKgUI-YvjWI, Like Count: Not Available
# Comment ID: _2viQ_Qnc68ki9xsFeN2y1_ZiHYcZC8Qv1GyHfwqr7Y, Like Count: Not Available
# Comment ID: _2viQ_Qnc69mci30y5muwQXNMaeCmIvZ4ca8l_4zPmA, Like Count: Not Available
# Comment ID: _2viQ_Qnc68cxHfQzecR1L9f-hbLNIJ7VxpCZtctPMk, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-G71VMp3dR76dfQTcrRHpiNXJh2jm8V_M, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-3Nk200KmVtS-kiCS_1CjKJsMIbXakyfI, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-UzHByAP8y3BxG633jelEC_fxtFRUvLSA, Like Count: Not Available
# Comment ID: _2viQ_Qnc68LpP5gDCaWQuiywObesTUlRgSQExMVMac, Like Count: Not Available
# Error fetching like count for Comment ID: z12xc3ly4x3uttmci22xff24nqqxwb0je04, Error: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&id=z12xc3ly4x3uttmci22xff24nqqxwb0je04&key=AIzaSyAB3U_dJamEjJInolpVQdrp70KgMHzrBKA&alt=json returned "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.". Details: "[{'message': "One or more specified comment threads could not be found. Check the value of the request's <code>id</code> parameter to ensure that it is correct.", 'domain': 'youtube.commentThread', 'reason': 'commentThreadNotFound', 'location': 'id', 'locationType': 'parameter'}]">
# Comment ID: z12xc3ly4x3uttmci22xff24nqqxwb0je04, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-PfOjDtTwbTalW_5TRtvBKMcHZdDrcI2o, Like Count: Not Available
# Comment ID: _2viQ_Qnc69GH3FQl348HonbRxpbmtsR5CUei0zkJog, Like Count: Not Available
# Comment ID: _2viQ_Qnc69S12dQyWLf0QBgUD29OMTe71geFOn4PJA, Like Count: Not Available
# Comment ID: _2viQ_Qnc69Ic8yEMHsemUQiq01-kwwqnbDowMO9kdM, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-qHJ_u9Yv84vj4yOAPLUL3ZibCc7b-vBI, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_HU65mTzCmXnjA-WLt7XqxqPj7EwAtlO0, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-jk58CPwBnqfbM6oByJH5oPvCtKecLQyo, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_fgKR1W7-k1lbVURi8hVbMlQAMSOCSnyk, Like Count: Not Available
# Comment ID: _2viQ_Qnc69MEEHHJxZ427KX8MlljJPnUC2YBbvbWwY, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_RKHVetk9kLzx8ZC62_J7y73FWFSBTe8Q, Like Count: Not Available
# Comment ID: _2viQ_Qnc68TufyXKiTwky80ewSPbhRiD5XFHrJH9lg, Like Count: Not Available
# Comment ID: _2viQ_Qnc689m-WiwOwvrQU7LvkLAgspnfXL8ovE0ME, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_1Hq9MGlefkBIszt9rYD3S_CozADvMhQ4, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA, Like Count: Not Available
# Comment ID: _2viQ_Qnc6-pY-1yR6K2FhmC5i48-WuNx5CumlHLDAI, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_k_n_Bse9zVhJP8tJReZpo8uM2uZfnzDs, Like Count: Not Available
# Comment ID: _2viQ_Qnc6_yBt8UGMWyg3vh0PulTqcqyQtdE7d4Fl0, Like Count: Not Available
# Comment ID: _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA, Like Count: Not Available
