# %% [markdown]
# - Current Num_Layers:  4
# - Current Dropout:  0.4
# - Current Learning Rate:  0.0007
# - Current Num_Epochs:  40
#
# # RNN
# - Train accuracy: 0.995116651058197
# - Validation accuracy: 0.9110429286956787
# - Test accuracy: 0.9242819547653198
# Train Confusion Matrix:
#
# [[1004    0]
#
#  [9     830]]
#
# Validation Confusion Matrix:
#
# [[170   6]
#  [ 23 127]]
#
# Test Confusion Matrix:
#
# [[187   5]
#  [ 24 167]]
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1004
#            1       1.00      0.99      0.99       839
#
#     accuracy                           1.00      1843
#    macro avg       1.00      0.99      1.00      1843
# weighted avg       1.00      1.00      1.00      1843
#
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       176
#            1       0.95      0.85      0.90       150
#
#     accuracy                           0.91       326
#    macro avg       0.92      0.91      0.91       326
# weighted avg       0.91      0.91      0.91       326
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       192
#            1       0.97      0.87      0.92       191
#
#     accuracy                           0.92       383
#    macro avg       0.93      0.92      0.92       383
# weighted avg       0.93      0.92      0.92       383
#
# # Bi-RNN
#
# - Train accuracy: 1.0
# - Validation accuracy: 0.89570552110672
# - Test accuracy: 0.9321148991584778
#
# Train Confusion Matrix:
# [[1004    0]
#  [   0  839]]
# Validation Confusion Matrix:
# [[167   9]
#  [ 25 125]]
# Test Confusion Matrix:
# [[188   4]
#  [ 22 169]]
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1004
#            1       1.00      1.00      1.00       839
#
#     accuracy                           1.00      1843
#    macro avg       1.00      1.00      1.00      1843
# weighted avg       1.00      1.00      1.00      1843
#
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       176
#            1       0.93      0.83      0.88       150
#
#     accuracy                           0.90       326
#    macro avg       0.90      0.89      0.89       326
# weighted avg       0.90      0.90      0.90       326
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       192
#            1       0.98      0.88      0.93       191
#
#     accuracy                           0.93       383
#    macro avg       0.94      0.93      0.93       383
# weighted avg       0.94      0.93      0.93       383
#
# # Attention LTSM
#
# Train accuracy: 0.9994574189186096
# Validation accuracy: 0.89570552110672
# Test accuracy: 0.93733681462141
#
# Train Confusion Matrix:
# [[1004    0]
#  [   1  838]]
# Validation Confusion Matrix:
# [[166  10]
#  [ 24 126]]
# Test Confusion Matrix:
# [[185 7]
#  [ 17 174]]
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1004
#            1       1.00      1.00      1.00       839
#
#     accuracy                           1.00      1843
#    macro avg       1.00      1.00      1.00      1843
# weighted avg       1.00      1.00      1.00      1843
#
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91       176
#            1       0.93      0.84      0.88       150
#
#     accuracy                           0.90       326
#    macro avg       0.90      0.89      0.89       326
# weighted avg       0.90      0.90      0.90       326
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       192
#            1       0.96      0.91      0.94       191
#
#     accuracy                           0.94       383
#    macro avg       0.93      0.93      0.93       383
# weighted avg       0.93      0.93      0.93       383

# %% [markdown]
# # RNN LikeCount
# - batch_size = 32
# - embedding_dict = tokenizer.vocab_size
# - embedding_size = 128
# - hidden_size = 256
# - num_layers = 4
# - num_classes = 2
# - dropout = 0.4
# - learning_rate = 0.001
# - num_epochs = 40
#
# Train accuracy: 0.9994574189186096
# Validation accuracy: 0.8834356069564819
# Test accuracy: 0.9242819547653198
#
# Train Confusion Matrix:
# [[1004    0]
#  [   1  838]]
# Validation Confusion Matrix:
# [[159  17]
#  [ 21 129]]
# Test Confusion Matrix:
# [[181  11]
#  [ 18 173]]
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1004
#            1       1.00      1.00      1.00       839
#
#     accuracy                           1.00      1843
#    macro avg       1.00      1.00      1.00      1843
# weighted avg       1.00      1.00      1.00      1843
#
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       176
#            1       0.88      0.86      0.87       150
#
#     accuracy                           0.88       326
#    macro avg       0.88      0.88      0.88       326
# weighted avg       0.88      0.88      0.88       326
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       192
#            1       0.94      0.91      0.92       191
#
#     accuracy                           0.92       383
#    macro avg       0.92      0.92      0.92       383
# weighted avg       0.92      0.92      0.92       383

# %% [markdown]
# # Summary + Comments
#
# Train accuracy: 0.9972870349884033
# Validation accuracy: 0.8987730145454407
# Test accuracy: 0.9190600514411926
# Train Confusion Matrix:
# [[1004    0]
#  [   5  834]]
# Validation Confusion Matrix:
# [[172   4]
#  [ 29 121]]
# Test Confusion Matrix:
# [[180  12]
#  [ 19 172]]
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1004
#            1       1.00      0.99      1.00       839
#
#     accuracy                           1.00      1843
#    macro avg       1.00      1.00      1.00      1843
# weighted avg       1.00      1.00      1.00      1843
#
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91       176
#            1       0.97      0.81      0.88       150
#
#     accuracy                           0.90       326
#    macro avg       0.91      0.89      0.90       326
# weighted avg       0.91      0.90      0.90       326
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       192
#            1       0.93      0.90      0.92       191
#
#     accuracy                           0.92       383
#    macro avg       0.92      0.92      0.92       383
# weighted avg       0.92      0.92      0.92       383

# %% [markdown]
# # Comments + Summary
#
# Train accuracy: 0.9875203371047974
# Validation accuracy: 0.9233129024505615
# Test accuracy: 0.939947783946991
#
# Train Confusion Matrix:
# [[1004    0]
#  [  23  816]]
# Validation Confusion Matrix:
# [[167   9]
#  [ 16 134]]
# Test Confusion Matrix:
# [[186   6]
#  [ 17 174]]
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1004
#            1       1.00      0.97      0.99       839
#
#     accuracy                           0.99      1843
#    macro avg       0.99      0.99      0.99      1843
# weighted avg       0.99      0.99      0.99      1843
#
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       176
#            1       0.94      0.89      0.91       150
#
#     accuracy                           0.92       326
#    macro avg       0.92      0.92      0.92       326
# weighted avg       0.92      0.92      0.92       326
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       192
#            1       0.97      0.91      0.94       191
#
#     accuracy                           0.94       383
#    macro avg       0.94      0.94      0.94       383
# weighted avg       0.94      0.94      0.94       383

# %% [markdown]
# # FeatureCombination
#
# - embedding_dict = tokenizer.vocab_size
# - embedding_size = 128
# - hidden_size = 256
# - num_layers = 4
# - num_classes = 2
# - dropout = 0.4
# - learning_rate = 0.0007
# - num_epochs = 30
#
# Train accuracy: 1.0
# Validation accuracy: 0.9233129024505615
# Test accuracy: 0.94255874673629
#
# Train Confusion Matrix:
# [[1007    0]
#  [   0  836]]
# Validation Confusion Matrix:
# [[166   7]
#  [ 18 135]]
# Test Confusion Matrix:
# [[182  10]
#  [ 12 179]]
# Train Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1007
#            1       1.00      1.00      1.00       836
#
#     accuracy                           1.00      1843
#    macro avg       1.00      1.00      1.00      1843
# weighted avg       1.00      1.00      1.00      1843
#
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       173
#            1       0.95      0.88      0.92       153
#
#     accuracy                           0.92       326
#    macro avg       0.93      0.92      0.92       326
# weighted avg       0.92      0.92      0.92       326
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       192
#            1       0.94      0.95      0.94       191
#
#     accuracy                           0.94       383
#    macro avg       0.94      0.94      0.94       383
# weighted avg       0.94      0.94      0.94       383
