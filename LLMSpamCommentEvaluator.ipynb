# %%
# %pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.5 MB/s eta 0:00:00
# ...

# %%
from openai import OpenAI
from google.colab import userdata

# %%
client = OpenAI(api_key=userdata.get("GPT_API_KEY"))

human_comment="Great job 👏 go watch yeonmi park to save North Korea that need to be freedi"
spam_comment="Huh, anyway check out this you[tube] channel: kobyoshi02"


completion = client.chat.completions.create(
  model="gpt-3.5",
  messages=[
    {"role": "user", "content": "Evaluate the following YouTube comment whether it is a bot comment or a human comment: {}".format(human_comment)},
    {"role": "user", "content": "Evaluate the following YouTube comment whether it is a bot comment or a human comment: {}".format(spam_comment)}
  ]
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-5-57e0f3084dfc> in <cell line: 7>()
#       5
#       6
# ----> 7 completion = client.chat.completions.create(
#       8   model="gpt-3.5",
#       9   messages=[
#
# /usr/local/lib/python3.10/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     273                         msg = f"Missing required argument: {quote(missing[0])}"
#     274                 raise TypeError(msg)
# --> 275             return func(*args, **kwargs)
#     276
#     277         return wrapper  # type: ignore
#
# ...
